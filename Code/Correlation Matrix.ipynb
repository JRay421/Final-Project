# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Data

# %%
bc = pd.read_csv('C:/Users/Student/Desktop/Group Project/archive/breast-cancer.csv')

# %% [markdown]
# ## Create correlation matrix on entire dataset

# %%
bc1 = bc.drop(['diagnosis'], axis=1)

# %%
bc1.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
bc1.corr(method='pearson')
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
bc1.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
# #T_c63f4_row0_col0,#T_c63f4_row1_col1,#T_c63f4_row1_col3,#T_c63f4_row2_col2,#T_c63f4_row3_col1,#T_c63f4_row3_col3,#T_c63f4_row4_col4,#T_c63f4_row5_col5,#T_c63f4_row6_col6,#T_c63f4_row7_col7,#T_c63f4_row8_col8,#T_c63f4_row9_col9,#T_c63f4_row10_col10,#T_c63f4_row11_col11,#T_c63f4_row12_col12,#T_c63f4_row13_col13,#T_c63f4_row14_col14,#T_c63f4_row15_col15,#T_c63f4_row16_col16,#T_c63f4_row17_col17,#T_c63f4_row18_col18,#T_c63f4_row19_col19,#T_c63f4_row20_col20,#T_c63f4_row21_col21,#T_c63f4_row22_col22,#T_c63f4_row23_col23,#T_c63f4_row24_col24,#T_c63f4_row25_col25,#T_c63f4_row26_col26,#T_c63f4_row27_col27,#T_c63f4_row28_col28,#T_c63f4_row29_col29,#T_c63f4_row30_col30{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c63f4_row0_col1,#T_c63f4_row0_col3,#T_c63f4_row17_col25,#T_c63f4_row24_col12,#T_c63f4_row30_col19,#T_c63f4_row30_col24{
#             background-color:  #5f7fe8;
#             color:  #000000;
# ...

# %% [markdown]
# ## Dataset with selected variables

# %%
Bc = bc[['area_mean', 'smoothness_mean', 'compactness_mean', 'symmetry_mean', 'concavity_mean', 'concave points_mean']]

# %% [markdown]
# ## Correlation Matrix

# %%
Bc.corr(method='pearson')
# Out:
#                      area_mean  smoothness_mean  compactness_mean  \
# area_mean             1.000000         0.177028          0.498502
# smoothness_mean       0.177028         1.000000          0.659123
# compactness_mean      0.498502         0.659123          1.000000
# symmetry_mean         0.151293         0.557775          0.602641
# concavity_mean        0.685983         0.521984          0.883121
# concave points_mean   0.823269         0.553695          0.831135
#
#                      symmetry_mean  concavity_mean  concave points_mean
# area_mean                 0.151293        0.685983             0.823269
# smoothness_mean           0.557775        0.521984             0.553695
# compactness_mean          0.602641        0.883121             0.831135
# symmetry_mean             1.000000        0.500667             0.462497
# concavity_mean            0.500667        1.000000             0.921391
# concave points_mean       0.462497        0.921391             1.000000
